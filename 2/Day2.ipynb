# %% [markdown]
# <a href="https://colab.research.google.com/github/kreetikastha/Python/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print(5)
print(5*12)
print(9+5)
# Out:
# 5
# 60
# 14

# %%
print("I am", 19, "years old.")
# Out:
# I am 19 years old.

# %%
#This is comment
print("This is comment")    #This comment
"""
This is comment
for more than one line
"""
print("This is comment")
# Out:
# This is comment
# This is comment
