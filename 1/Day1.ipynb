# %% [markdown]
# <a href="https://colab.research.google.com/github/kreetikastha/Python/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
#if and else statement
if 5>2:
    print("Five is greater than two!")
else:
  print("Five is not greater than two!")
# Out:
# Five is greater than two!

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %%
print("Hello"); print("Hey hey"); print("Bye bye!")
# Out:
# Hello
# Hey hey
# Bye bye!
