# %% [markdown]
# <a href="https://colab.research.google.com/github/kreetikastha/Python/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = str("Hello World")
print(x)
# Out:
# Hello World

# %%
x = int(20)
print(x)
# Out:
# 20

# %%
x="Apple"
print(x)
print(type(x))
# Out:
# Apple
# <class 'str'>

# %%
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
x = 20.5
print(x)
print(type(x))
# Out:
# 20.5
# <class 'float'>

# %%
x = 1j
print(x)
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %%
x = ["apple", "banana", "cherry"]
print(x)
print(type(x))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
x = ("apple", "banana", "cherry")
print(x)
print(type(x))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %%
x = range(6)
print(x)
print(type(x))
# Out:
# range(0, 6)
# <class 'range'>

# %%
x = {"name" : "John", "age" : 36}
print(x)
print(type(x))
# Out:
# {'name': 'John', 'age': 36}
# <class 'dict'>

# %%
x = {"apple", "banana", "cherry"}
print(x)
print(type(x))
# Out:
# {'apple', 'banana', 'cherry'}
# <class 'set'>

# %%
x = frozenset(("apple", "banana", "cherry"))
print(x)
print(type(x))
# Out:
# frozenset({'apple', 'banana', 'cherry'})
# <class 'frozenset'>

# %%
x = bool(5)
print(x)
print(type(x))
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>
# True
# <class 'bool'>

# %%
x = b"Hello"
print(x)
print(type(x))
# Out:
# b'Hello'
# <class 'bytes'>

# %%
x = bytearray(5)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(x)
print(type(x))
# Out:
# ...
# <class 'memoryview'>

# %%
x = None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>
