# %% [markdown]
# <a href="https://colab.research.google.com/github/kreetikastha/Python/blob/main/Day3ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 63
y = "Kritika"
print(x)
print(y)
# Out:
# 63
# Kritika

# %%
x = 63
x = "Kritika"
print(x)
# Out:
# Kritika

# %%
x = str(3)
y = int(3)
z = float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x = 5
y = "Kritika"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
y = "Kritika"
x = 'Kritika'
print(x)
print(y)
# Out:
# Kritika
# Kritika

# %%
x = 12
X = 15
print(x)
print(X)
# Out:
# 12
# 15

# %%
#Legal Variable
myvar = "Kritika"
my_var = "Kritika"
_my_var = "Kritika"
myVar = "Kritika"
MYVAR = "JKritika"
myvar2 = "Kritika"

#Illegal Variable
"""2myvar = "Kritika"
my-var = "Kritika"
my var = "Kritika""""

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x = "Python is programming language"
print(x)
# Out:
# Python is programming language

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
"""x = 5
y = "John"
print(x + y)"""
# Out:
# 'x = 5\ny = "John"\nprint(x + y)'

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
